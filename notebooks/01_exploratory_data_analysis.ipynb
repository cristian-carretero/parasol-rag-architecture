# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
parquet_path = Path("../data/processed/outdoor/A162ALXP01/A162ALXP01_mpp.parquet")

df_mpp = pd.read_parquet(parquet_path)
print(df_mpp.head())
# Out:
#             Timestamp  Voltage_V  Current_A   Power_W
# 0 2026-03-14 06:00:00   0.089745  -0.000056 -0.000005
# 1 2026-03-14 06:00:01   0.089571  -0.000064 -0.000006
# 2 2026-03-14 06:00:02   0.089657  -0.000074 -0.000007
# 3 2026-03-14 06:00:03   0.089551  -0.000096 -0.000009
# 4 2026-03-14 06:00:04   0.089370  -0.000056 -0.000005
